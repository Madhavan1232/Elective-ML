# %%
from ydata_profiling import ProfileReport
import pandas as pd

df = pd.read_csv("Data/DA314_S9_EmployeePerformance_Cleaned_Data_Concept.csv")
profile = ProfileReport(df)
profile.to_file("Employee_Performance_Report.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df1 = pd.read_csv("Data/DA314_S9_EmployeePerformance_Data_Concept.csv")
profile1 = ProfileReport(df1)
profile1.to_file("Employee_Performance_Report1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df2 = pd.read_excel("Data/DA314_S9_EmployeePerformance_Data_Concept.xlsx")
profile2 = ProfileReport(df2)
profile2.to_file("Employee_Performance_Report2.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df3 = pd.read_excel("Data/DA314_S9_EmployeePerformance_Cleaned_Data_Concept.xlsx")
profile3 = ProfileReport(df3)
profile3.to_file("Employee_Performance_Report3.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
