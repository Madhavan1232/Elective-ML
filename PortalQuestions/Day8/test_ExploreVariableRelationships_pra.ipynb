# %%
# Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

plt.style.use('default')
sns.set_palette("husl")

# %%
# Select features for pairplot
pairplot_features = ['JobSatisfaction', 'EnvironmentSatisfaction', 'MonthlyIncome', 'Attrition']
pairplot_data = df[pairplot_features].copy()

# Create pairplot
pairplot = sns.pairplot(pairplot_data, hue='Attrition', 
                        palette={'Yes': '#e74c3c', 'No': '#3498db'},
                        diag_kind='kde', 
                        plot_kws={'alpha': 0.6, 's': 50},
                        diag_kws={'alpha': 0.7, 'linewidth': 2})

pairplot.fig.suptitle('Pairplot: JobSatisfaction, EnvironmentSatisfaction, and MonthlyIncome by Attrition', 
                      fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()
