# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('Data/DA314_S5_OrderDetails_Data_Concept.csv')

# %%
sns.histplot(data = df , x = 'total_amount' , color = 'skyblue' , kde = True)
plt.show()

# %%
sns.boxplot(data = df , x = 'total_amount' , color = 'pink')
plt.show()
